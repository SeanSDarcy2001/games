# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanSDarcy2001/games/blob/main/blackJackGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random

# %%
class Player() :

  def __init__(self, Name) :
    self.name = Name
    self.hand = []
    self.chips = 0

  def buyIn(self, amnt) :
    self.chips = amnt

  def bet(self, amnt) :
    if amnt <= self.chips :
      self.chips -= amnt
      return amnt
    else :
      print("Not enough chips!")

  def collect(self, amnt) :
    self.chips += amnt
  
  def amIup(self) :
    return self.chips
  
  def getName(self) :
    return self.name

  def updateHand(self, card) :
    self.hand.append(card)
  
  def getHand(self) :
    value = 0
    numAces = 0
    for i in range(len(self.hand)) :
      print(self.hand[i].getCard())
      value += self.hand[i].value()

      if self.hand[i].card == "Ace" :
        numAces += 1
      
    while(value > 21 and numAces > 0) :
      value -= 10
      numAces -= 1
    return value

  def resetHand(self) :
    self.hand = []

    
class Card() :

  def __init__(self, suit, card) :
    self.suit = suit
    self.card = card

  def getCard(self) :
    return self.card + " of " + self.suit
  
  def value(self) :
    if self.card == "Ace" :
      val = 11
    elif self.card == "2" :
      val = 2
    elif self.card == "3" :
      val = 3
    elif self.card == "4" :
      val = 4
    elif self.card == "5" :
      val = 5
    elif self.card == "6" :
      val = 6
    elif self.card == "7" :
      val = 7
    elif self.card == "8" :
      val = 8
    elif self.card == "9" :
      val = 9
    elif self.card == "10" or self.card == "Jack" or self.card == "Queen" or self.card == "King":
      val = 10
    return val
    
class Deck() :
   def __init__(self) :
     
     self.suits = ["Spades", "Diamonds", "Clubs", "Hearts"]
     self.cards = ["Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]
     self.deck = []

     for suit in self.suits :
       for card in self.cards :
         self.deck.append(Card(suit, card))
    
   def shuffleDeck(self) :
     random.shuffle(self.deck)
  
   def draw(self) :
     return self.deck.pop()

   def cardsLeft(self) :
     return len(self.deck)


class Dealer() :
  def __init__(self, players) :
    self.deck = Deck()
    self.table = players
    self.hand = []
    
  def shuffle(self):
    self.deck.shuffleDeck()
  
  def deal(self) :
    for i in range(2) :
      for players in self.table :
        players.updateHand(self.deck.draw())
      self.hand.append(self.deck.draw())

  def whatsUp(self) :
    return self.hand[1].getCard()

  def whatsDown(self) :
    return self.hand[0].getCard()

  def hit(self, player) :
    player.updateHand(self.deck.draw())
  
  def pay(player, amnt) :
    player.collect(amnt)

  def getHand(self) :
    value = 0
    numAces = 0
    for i in range(len(self.hand)) :
      print(self.hand[i].getCard())
      value += self.hand[i].value()

      if self.hand[i].card == "Ace" :
        numAces += 1
      
    while(value > 21 and numAces > 0) :
      value -= 10
      numAces -= 1
    return value

  def dealerHit(self) :
    self.hand.append(self.deck.draw())

# %%
seby = Player("Seby")
oscar = Player("Oscar")
mohan = Player("Mohan")
ben = Player("Ben")


table = [ben, mohan, oscar, seby]
dealer = Dealer(table)
dealer.shuffle()
#dealer.deck.shuffleDeck()

dealer.table[0].buyIn(10)
dealer.table[1].buyIn(10)

bets = []
bets.append(dealer.table[0].bet(2))
bets.append(dealer.table[1].bet(2))

#initial deal
dealer.deal()
print("Dealer has: ", dealer.whatsUp())
for player in dealer.table :
  print("===================")
  print(player.getName()) 
  print(str(player.getHand()))

for player in dealer.table :
  busted = False
  stays = False
  while busted == False and stays == False :
    print("===================")
    print(player.getName(), "you have", str(player.getHand()))
    decision = input('Hit (press h), Stay (press s), Double Down (press d), Split (press 2)')
    if decision == 'h' :
      dealer.hit(player)
      if player.getHand() > 21 :
        busted = True
        print(player.getName(), "busted!")
    if decision == 's' :
      stays = True
      print(player.getName(), "stays at ", str(player.getHand()))

#now dealer
print("===================")
print("Dealer has", dealer.whatsUp(), "faceup.")
print("Dealer has", dealer.whatsDown(), "underneath.")
value = dealer.getHand()
print("Dealer has ", str(value))

busted = False
while dealer.getHand() < 17 and busted == False :
  dealer.dealerHit()
  value = dealer.getHand()
  print("===================")
  print("Dealer has ", str(value))
  if value > 21 :
    print("Dealer busts!")
    busted = True
# Out:
# Dealer has:  3 of Diamonds
# ===================
# Ben
# 2 of Diamonds
# 2 of Clubs
# 4
# ===================
# Mohan
# 10 of Hearts
# 8 of Clubs
# 18
# ===================
# Oscar
# 5 of Diamonds
# 6 of Clubs
# 11
# ===================
# Seby
# 6 of Hearts
# 10 of Diamonds
# 16
# ===================
# 2 of Diamonds
# 2 of Clubs
# Ben you have 4
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# 2 of Diamonds
# 2 of Clubs
# Ace of Clubs
# ===================
# 2 of Diamonds
# 2 of Clubs
# Ace of Clubs
# Ben you have 15
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# 2 of Diamonds
# 2 of Clubs
# Ace of Clubs
# Ben stays at  15
# ===================
# 10 of Hearts
# 8 of Clubs
# Mohan you have 18
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# 10 of Hearts
# 8 of Clubs
# Mohan stays at  18
# ===================
# 5 of Diamonds
# 6 of Clubs
# Oscar you have 11
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# 5 of Diamonds
# 6 of Clubs
# 2 of Spades
# ===================
# 5 of Diamonds
# 6 of Clubs
# 2 of Spades
# Oscar you have 13
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# 5 of Diamonds
# 6 of Clubs
# 2 of Spades
# 8 of Spades
# ===================
# 5 of Diamonds
# 6 of Clubs
# 2 of Spades
# 8 of Spades
# Oscar you have 21
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# 5 of Diamonds
# 6 of Clubs
# 2 of Spades
# 8 of Spades
# Oscar stays at  21
# ===================
# 6 of Hearts
# 10 of Diamonds
# Seby you have 16
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# 6 of Hearts
# 10 of Diamonds
# Seby stays at  16
# ===================
# Dealer has 3 of Diamonds faceup.
# Dealer has Queen of Spades underneath.
# Queen of Spades
# 3 of Diamonds
# Dealer has  13
# Queen of Spades
# 3 of Diamonds
# Queen of Spades
# 3 of Diamonds
# 4 of Hearts
# ===================
# Dealer has  17
# Queen of Spades
# 3 of Diamonds
# 4 of Hearts
