# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanSDarcy2001/games/blob/main/blackJackGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
class Player() :

  def __init__(self, Name) :
    self.name = Name
    self.hand = []
    self.chips = 0

  def buyIn(self, amnt) :
    self.chips = amnt

  def bet(self, amnt) :
    amnt = int(amnt)
    if amnt <= self.chips :
      self.chips -= amnt
      return amnt
    else :
      print("Not enough chips!")

  def collect(self, amnt) :
    self.chips += amnt
  
  def amIup(self) :
    return self.chips
  
  def getName(self) :
    return self.name

  def updateHand(self, card) :
    self.hand.append(card)
  
  def getHand(self) :
    value = 0
    numAces = 0
    cards = []
    for i in range(len(self.hand)) :
      cards.append(self.hand[i].getCard())
      value += self.hand[i].value()

      if self.hand[i].card == "Ace" :
        numAces += 1
      
    while(value > 21 and numAces > 0) :
      value -= 10
      numAces -= 1
    return cards, value

  def resetHand(self) :
    self.hand = []

    
class Card() :

  def __init__(self, suit, card) :
    self.suit = suit
    self.card = card

  def getCard(self) :
    return self.card + " of " + self.suit
  
  def value(self) :
    if self.card == "Ace" :
      val = 11
    elif self.card == "2" :
      val = 2
    elif self.card == "3" :
      val = 3
    elif self.card == "4" :
      val = 4
    elif self.card == "5" :
      val = 5
    elif self.card == "6" :
      val = 6
    elif self.card == "7" :
      val = 7
    elif self.card == "8" :
      val = 8
    elif self.card == "9" :
      val = 9
    elif self.card == "10" or self.card == "Jack" or self.card == "Queen" or self.card == "King":
      val = 10
    return val
    
class Deck() :
   def __init__(self) :
     
     self.suits = ["Spades", "Diamonds", "Clubs", "Hearts"]
     self.cards = ["Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]
     self.deck = []

     for suit in self.suits :
       for card in self.cards :
         self.deck.append(Card(suit, card))
    
   def shuffleDeck(self) :
     random.shuffle(self.deck)
  
   def draw(self) :
     return self.deck.pop()

   def cardsLeft(self) :
     return len(self.deck)


class Dealer() :
  def __init__(self, players) :
    self.deck = Deck()
    self.table = players
    self.hand = []
    
  def shuffle(self):
    self.deck.shuffleDeck()
  
  def deal(self) :
    for i in range(2) :
      for players in self.table :
        players.updateHand(self.deck.draw())
      self.hand.append(self.deck.draw())

  def whatsUp(self) :
    return self.hand[1].getCard()

  def whatsDown(self) :
    return self.hand[0].getCard()

  def hit(self, player) :
    player.updateHand(self.deck.draw())
  
  def pay(self, player, amnt) :
    player.collect(amnt)

  def getHand(self) :
    value = 0
    numAces = 0
    cards = []
    for i in range(len(self.hand)) :
      cards.append(self.hand[i].getCard())
      value += self.hand[i].value()

      if self.hand[i].card == "Ace" :
        numAces += 1
      
    while(value > 21 and numAces > 0) :
      value -= 10
      numAces -= 1
    return cards, value

  def dealerHit(self) :
    self.hand.append(self.deck.draw())
  
  def resetHand(self) :
    self.hand = []

# %%
def whoWon(dealer, bets) :
  for i, players in enumerate(dealer.table) :
    if players.getHand()[1] > 21 :
      print(players.getName(), "lost.")
      payout = int(bets[i])
      print(players.getName(), "loses", payout)
    elif players.getHand()[1] < dealer.getHand()[1] and dealer.getHand()[1] <= 21:
      print(players.getName(), "lost.")
      payout = int(bets[i])
      print(players.getName(), "loses", payout)
    elif dealer.getHand()[1] > 21 and  players.getHand()[1] <= 21:
      print(players.getName(), "wins!")
      payout = 2*  int(bets[i])
      dealer.pay(players, payout)
      print(players.getName(), "gets $", payout)
    elif dealer.getHand()[1] == players.getHand()[1] :
      print(players.getName(), "pushes!")
      payout = int(bets[i])
      dealer.pay(players, payout)
      print(players.getName(), "gets $", payout)
    else :
      print(players.getName(), "wins!")
      payout = 2*int(bets[i])
      dealer.pay(players, payout)
      print(players.getName(), "gets $", payout)
      

def takeBets(dealer) :
  bets = []
  for players in dealer.table :
    print(players.getName(),"you have", players.amIup())
    bet = input('Place your bet:')
    bets.append(players.bet(bet))
  return bets

# %%
p2 = Player("Mohan")
p1 = Player("Oscar")
p3 = Player("Seby")



table = [p1, p2, p3]
dealer = Dealer(table)
dealer.shuffle()
#dealer.deck.shuffleDeck()

dealer.table[0].buyIn(10)
dealer.table[1].buyIn(10)
dealer.table[2].buyIn(10)

exit = True

while exit :

  bets = takeBets(dealer)


  #initial deal
  dealer.deal()
  for player in dealer.table :
    print("===================")
    print(player.getName())
    print("Hand:", player.getHand()[0])
    print("Value:", str(player.getHand()[1]))

  for i, player in enumerate(dealer.table) :
    busted = False
    stays = False
    while busted == False and stays == False :
      print("===================")
      print("Dealer has: ", dealer.whatsUp(), "faceup.")
      print("===================")
      hand = player.getHand()
      print(hand[0])
      print(player.getName(), "you have", hand[1])
      decision = input('Hit (press h), Stay (press s), Double Down (press d), Split (press 2)')
      if decision == 'h' :
        dealer.hit(player)
        newHand = player.getHand()
        card = newHand[0][-1]
        print(player.getName(), "hits...", card)
        print(player.getName(), "you have", newHand[1])
        if newHand[1] > 21 :
          busted = True
          print(player.getName(), "busted!")
      if decision == 'd' and (int(bets[i]) <= int(player.amIup())):
        player.bet(int(bets[i]))
        bets[i] = 2*int(bets[i])
        print(player.getName(), "doubles down.")
        dealer.hit(player)
        newHand = player.getHand()
        card = newHand[0][-1]
        print(player.getName(), "got", card, "on the double")
        stays = True
      if decision == 's' :
        stays = True
        print(player.getName(), "stays at ", hand[1])

  #now dealer
  print("===================")
  print("Dealer has", dealer.whatsUp(), "faceup.")
  print("Dealer has", dealer.whatsDown(), "underneath.")
  value = dealer.getHand()
  print("Dealer has ", str(value))

  busted = False
  while dealer.getHand()[1] < 17 and busted == False :
    dealer.dealerHit()
    print("Dealer hits...", dealer.getHand()[0][-1])
    value = dealer.getHand()[1]
    print("===================")
    print("Dealer has ", str(value))
    if value > 21 :
      print("Dealer busts!")
      busted = True


  whoWon(dealer, bets)

  dealer.resetHand()
  for players in dealer.table :
    players.resetHand()

  cont = input("Continue playing? (y/n)")
  if cont == 'n' :
    exit = False
# Out:
# Oscar you have 10
# Place your bet:2
# Mohan you have 10
# Place your bet:3
# Seby you have 10
# Place your bet:2
# ===================
# Oscar
# Hand: ['3 of Clubs', '4 of Clubs']
# Value: 7
# ===================
# Mohan
# Hand: ['2 of Clubs', '3 of Spades']
# Value: 5
# ===================
# Seby
# Hand: ['6 of Hearts', 'Queen of Diamonds']
# Value: 16
# ===================
# Dealer has:  King of Spades faceup.
# ===================
# ['3 of Clubs', '4 of Clubs']
# Oscar you have 7
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Oscar hits... 9 of Clubs
# Oscar you have 16
# ===================
# Dealer has:  King of Spades faceup.
# ===================
# ['3 of Clubs', '4 of Clubs', '9 of Clubs']
# Oscar you have 16
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Oscar stays at  16
# ===================
# Dealer has:  King of Spades faceup.
# ===================
# ['2 of Clubs', '3 of Spades']
# Mohan you have 5
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Mohan hits... 5 of Spades
# Mohan you have 10
# ===================
# Dealer has:  King of Spades faceup.
# ===================
# ['2 of Clubs', '3 of Spades', '5 of Spades']
# Mohan you have 10
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Mohan hits... 6 of Spades
# Mohan you have 16
# ===================
# Dealer has:  King of Spades faceup.
# ===================
# ['2 of Clubs', '3 of Spades', '5 of Spades', '6 of Spades']
# Mohan you have 16
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Mohan hits... 10 of Hearts
# Mohan you have 26
# Mohan busted!
# ===================
# Dealer has:  King of Spades faceup.
# ===================
# ['6 of Hearts', 'Queen of Diamonds']
# Seby you have 16
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Seby stays at  16
# ===================
# Dealer has King of Spades faceup.
# Dealer has 4 of Spades underneath.
# Dealer has  (['4 of Spades', 'King of Spades'], 14)
# Dealer hits... 2 of Hearts
# ===================
# Dealer has  16
# Dealer hits... 4 of Diamonds
# ===================
# Dealer has  20
# Oscar lost.
# Oscar loses 2
# Mohan lost.
# Mohan loses 3
# Seby lost.
# Seby loses 2
# Continue playing? (y/n)y
# Oscar you have 8
# Place your bet:4
# Mohan you have 7
# Place your bet:7
# Seby you have 8
# Place your bet:5
# ===================
# Oscar
# Hand: ['10 of Spades', 'Ace of Spades']
# Value: 21
# ===================
# Mohan
# Hand: ['8 of Hearts', 'King of Diamonds']
# Value: 18
# ===================
# Seby
# Hand: ['7 of Hearts', 'Jack of Clubs']
# Value: 17
# ===================
# Dealer has:  Ace of Diamonds faceup.
# ===================
# ['10 of Spades', 'Ace of Spades']
# Oscar you have 21
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Oscar stays at  21
# ===================
# Dealer has:  Ace of Diamonds faceup.
# ===================
# ['8 of Hearts', 'King of Diamonds']
# Mohan you have 18
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Mohan stays at  18
# ===================
# Dealer has:  Ace of Diamonds faceup.
# ===================
# ['7 of Hearts', 'Jack of Clubs']
# Seby you have 17
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Seby stays at  17
# ===================
# Dealer has Ace of Diamonds faceup.
# Dealer has 5 of Diamonds underneath.
# Dealer has  (['5 of Diamonds', 'Ace of Diamonds'], 16)
# Dealer hits... King of Clubs
# ===================
# Dealer has  16
# Dealer hits... Jack of Hearts
# ===================
# Dealer has  26
# Dealer busts!
# Oscar wins!
# Oscar gets $ 8
# Mohan wins!
# Mohan gets $ 14
# Seby wins!
# Seby gets $ 10
# Continue playing? (y/n)y
# Oscar you have 12
# Place your bet:6
# Mohan you have 14
# Place your bet:3
# Seby you have 13
# Place your bet:10
# ===================
# Oscar
# Hand: ['10 of Diamonds', 'Queen of Hearts']
# Value: 20
# ===================
# Mohan
# Hand: ['8 of Diamonds', '4 of Hearts']
# Value: 12
# ===================
# Seby
# Hand: ['9 of Diamonds', '8 of Spades']
# Value: 17
# ===================
# Dealer has:  5 of Clubs faceup.
# ===================
# ['10 of Diamonds', 'Queen of Hearts']
# Oscar you have 20
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Oscar stays at  20
# ===================
# Dealer has:  5 of Clubs faceup.
# ===================
# ['8 of Diamonds', '4 of Hearts']
# Mohan you have 12
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# Mohan hits... Queen of Clubs
# Mohan you have 22
# Mohan busted!
# ===================
# Dealer has:  5 of Clubs faceup.
# ===================
# ['9 of Diamonds', '8 of Spades']
# Seby you have 17
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Seby stays at  17
# ===================
# Dealer has 5 of Clubs faceup.
# Dealer has 6 of Diamonds underneath.
# Dealer has  (['6 of Diamonds', '5 of Clubs'], 11)
# Dealer hits... 9 of Hearts
# ===================
# Dealer has  20
# Oscar pushes!
# Oscar gets $ 6
# Mohan lost.
# Mohan loses 3
# Seby lost.
# Seby loses 10
# Continue playing? (y/n)y
# Oscar you have 12
# Place your bet:2
# Mohan you have 11
# Place your bet:5
# Seby you have 3
# Place your bet:3
# ===================
# Oscar
# Hand: ['Queen of Spades', '10 of Clubs']
# Value: 20
# ===================
# Mohan
# Hand: ['7 of Diamonds', 'Ace of Hearts']
# Value: 18
# ===================
# Seby
# Hand: ['Jack of Diamonds', '7 of Spades']
# Value: 17
# ===================
# Dealer has:  9 of Spades faceup.
# ===================
# ['Queen of Spades', '10 of Clubs']
# Oscar you have 20
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Oscar stays at  20
# ===================
# Dealer has:  9 of Spades faceup.
# ===================
# ['7 of Diamonds', 'Ace of Hearts']
# Mohan you have 18
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Mohan stays at  18
# ===================
# Dealer has:  9 of Spades faceup.
# ===================
# ['Jack of Diamonds', '7 of Spades']
# Seby you have 17
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)s
# Seby stays at  17
# ===================
# Dealer has 9 of Spades faceup.
# Dealer has 2 of Spades underneath.
# Dealer has  (['2 of Spades', '9 of Spades'], 11)
# Dealer hits... 2 of Diamonds
# ===================
# Dealer has  13
# Dealer hits... 7 of Clubs
# ===================
# Dealer has  20
# Oscar pushes!
# Oscar gets $ 2
# Mohan lost.
# Mohan loses 5
# Seby lost.
# Seby loses 3
# Continue playing? (y/n)y
# Oscar you have 12
# Place your bet:4
# Mohan you have 6
# Place your bet:6
# Seby you have 0
# Place your bet:2
# Not enough chips!
# ===================
# Oscar
# Hand: ['Ace of Clubs', '6 of Clubs']
# Value: 17
# ===================
# Mohan
# Hand: ['3 of Diamonds', '5 of Hearts']
# Value: 8
# ===================
# Seby
# Hand: ['3 of Hearts', 'Jack of Spades']
# Value: 13
# ===================
# Dealer has:  8 of Clubs faceup.
# ===================
# ['Ace of Clubs', '6 of Clubs']
# Oscar you have 17
# Hit (press h), Stay (press s), Double Down (press d), Split (press 2)h
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-ab46b63ba6b3> in <module>()
#      41       decision = input('Hit (press h), Stay (press s), Double Down (press d), Split (press 2)')
#      42       if decision == 'h' :
# ---> 43         dealer.hit(player)
#      44         newHand = player.getHand()
#      45         card = newHand[0][-1]
#
# <ipython-input-82-fbbba905c6e2> in hit(self, player)
#     124
#     125   def hit(self, player) :
# --> 126     player.updateHand(self.deck.draw())
#     127
#     128   def pay(self, player, amnt) :
#
# <ipython-input-82-fbbba905c6e2> in draw(self)
#      96
#      97    def draw(self) :
# ---> 98      return self.deck.pop()
#      99
#     100    def cardsLeft(self) :
#
# IndexError: pop from empty list
